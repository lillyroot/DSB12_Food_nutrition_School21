# %%
import pandas as pd

# %%
df = pd.read_csv('data/dish_nutr.csv')
df.sort_values('Molybdenum', ascending=False)['Potassium']
# Out:
# 887     121.446809
# 2817    104.191489
# 1996     80.085106
# 2359     80.085106
# 1644     77.872340
#            ...
# 2135      0.000000
# 994       0.000000
# 993       0.000000
# 987       0.000000
# 345       0.000000
# Name: Potassium, Length: 2838, dtype: float64

# %%
list = (df.iloc[:, 4:] > 0).sum().sort_values(ascending=False).index.to_list()

# %%
list
# Out:
# ['Protein',
#  'Sodium',
#  'fat',
#  'Total carbohydrates',
#  'Iron',
#  'Calcium',
#  'Saturated fat',
#  'Dietary Fiber',
#  'Potassium',
#  'Cholesterol',
#  'Riboflavin',
#  'Niacin',
#  'Thiamin',
#  'Vitamin C',
#  'Magnesium',
#  'Zinc',
#  'Copper',
#  'Phosphorus',
#  'Vitamin B6',
#  'Folate',
#  'Selenium',
#  'Choline',
#  'Vitamin A',
#  'Vitamin E',
#  'Vitamin B12',
#  'Manganese',
#  'Pantothenic acid',
#  'Vitamin D',
#  'Vitamin K',
#  'Added sugars',
#  'Molybdenum',
#  'Biotin']
